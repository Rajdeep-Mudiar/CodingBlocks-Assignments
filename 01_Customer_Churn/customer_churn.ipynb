# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df=pd.read_excel("Telco_customer_churn.xlsx")
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %% [markdown]
# # EDA

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %% [markdown]
# ## Insights
# Male nd female ratio is almost same in this dataset

# %% [markdown]
# ## Histogram with a Kernel Density Estimate (KDE) curve
# ### Tenure Months vs Customer Count

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'],bins=30,kde=True)
plt.xlabel("Tenure Months")
plt.ylabel("Customer Count")
plt.show()

# %% [markdown]
# ## Box Plot (Box-and-Whisker Plot)
# X-axis (Churn Label): Customer churn status (e.g., Yes or No).
#
# Y-axis (Tenure Months): How long the customer has stayed with the company.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Tenure Months',data=df)
# Out:
# <Axes: xlabel='Churn Label', ylabel='Tenure Months'>

# %% [markdown]
# ## Histogram with a Kernel Density Estimate (KDE) curve
# ### Monthly Charges vs Customer Count

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'],bins=30,kde=True)
plt.xlabel("Monthly Charges")
plt.ylabel("Customer Count")
plt.show()

# %%
df['Monthly Charges'].max()
# Out:
# np.float64(118.75)

# %%
df['Monthly Charges'].min()
# Out:
# np.float64(18.25)

# %% [markdown]
# ## Box Plot (Box-and-Whisker Plot)
# X-axis (Churn Label): Customer churn status (e.g., Yes or No).
#
# Y-axis (Monthly Charges): Amount charged per month.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Monthly Charges',data=df)
plt.show()

# %%
df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# <StringArray>
# ['Month-to-month', 'Two year', 'One year']
# Length: 3, dtype: str

# %% [markdown]
# ## Count Plot
# X-axis (Contract): Contract type (e.g., Month-to-month, One year, Two year).
#
# Y-axis: Number of customers.
#
# Color (hue='Churn Label'): Separates customers by churn status (Yes/No).

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract',hue='Churn Label',data=df)
plt.xlabel('Contract')
# Out:
# Text(0.5, 0, 'Contract')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
df['Internet Service'].unique()
# Out:
# <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str

# %% [markdown]
# ## Count Plot
# X-axis (Internet Service): Types of internet service (e.g., DSL, Fiber optic, No internet service).
#
# Y-axis (Count): Number of customers.
#
# Hue (Churn Label): Separates customers into churned (Yes) and retained (No).

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service', hue='Churn Label',data=df)
plt.xlabel("Internet Service")
plt.ylabel("Count")
plt.title("Internet Service vs Count")
plt.show()

# %% [markdown]
# ## Count Plot
# X-axis (Payment Method): Different payment methods used by customers.
#
# Y-axis (Count): Number of customers.
#
# Hue (Churn Label): Splits customers into churned (Yes) and retained (No).

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Payment Method', hue='Churn Label',data=df)
plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.title("Payment Method vs Count")
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# <StringArray>
# [             'Mailed check',          'Electronic check',
#  'Bank transfer (automatic)',   'Credit card (automatic)']
# Length: 4, dtype: str

# %%
df['Tech Support'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str

# %% [markdown]
# ## Count Plot
# X-axis (Tech Support): Whether customers have tech support. --> Yes,No,No internet service(if present)
#
# Y-axis (Count): Number of customers.
#
# Hue (Churn Label):
# Yes → Customer churned,
# No → Customer stayed

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Tech Support', hue='Churn Label',data=df)
plt.xlabel("Tech Support")
plt.ylabel("Count")
plt.title("Tech Support vs Count")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %% [markdown]
# ## Count Plot
# X-axis (Dependents) -->
# Yes → Customer has dependents (children, family members, etc.),
# No → Customer has no dependents
#
# Y-axis (Count) -->
# Number of customers
#
# Hue (Churn Label) -->
# Yes → Customer churned,
# No → Customer stayed

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Dependents', hue='Churn Label',data=df)
plt.xlabel("Dependents")
plt.ylabel("Count")
plt.title("Dependents vs Count")
plt.show()

# %%
avg_tenure=df.groupby('Churn Label')['Tenure Months'].mean()
print(avg_tenure)
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df['Churn Value'].unique()
# Out:
# array([1, 0])

# %%
numericals_cols=['Tenure Months','Monthly Charges','Churn Value','Churn Score','CLTV']
correlation_matrix=df[numericals_cols].corr()
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
contract_churn=pd.crosstab(df['Contract'],df['Churn Label'])
contract_churn
# Out:
# Churn Label       No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
contract_churn=pd.crosstab(df['Contract'],df['Churn Label'],normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
df['Tenure Months'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure Months, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %% [markdown]
# ## Insights
# Total Charges column is object type so we convert it to float type

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %% [markdown]
# **bold text**## Insights
# Total Charges column have 11 null values we need to fill those with 0

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].sum()
# Out:
# np.int64(0)

# %%
# null value in Total Charges column is replaced by 0
df['Total Charges']=df['Total Charges'].fillna(0)

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
# Dropping the unnecessary columns
drop_columns=["Count","CustomerID","Country","State","Zip Code","Latitude","Longitude","Lat Long","Churn Label","Churn Score","Churn Reason"
,"CLTV"]
df.drop(drop_columns,axis=1,inplace=True)
df
# Out:
#               City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 0      Los Angeles    Male             No      No         No              2
# 1      Los Angeles  Female             No      No        Yes              2
# 2      Los Angeles  Female             No      No        Yes              8
# 3      Los Angeles  Female             No     Yes        Yes             28
# 4      Los Angeles    Male             No      No        Yes             49
# ...            ...     ...            ...     ...        ...            ...
# 7038       Landers  Female             No      No         No             72
# 7039      Adelanto    Male             No     Yes        Yes             24
# 7040         Amboy  Female             No     Yes        Yes             72
# 7041  Angelus Oaks  Female             No     Yes        Yes             11
# 7042  Apple Valley    Male             No      No         No             66
#
# ...

# %%
# Dropping the City column
df.drop(["City"],axis=1,inplace=True)
df
# Out:
#       Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0       Male             No      No         No              2           Yes
# 1     Female             No      No        Yes              2           Yes
# 2     Female             No      No        Yes              8           Yes
# 3     Female             No     Yes        Yes             28           Yes
# 4       Male             No      No        Yes             49           Yes
# ...      ...            ...     ...        ...            ...           ...
# 7038  Female             No      No         No             72           Yes
# 7039    Male             No     Yes        Yes             24           Yes
# 7040  Female             No     Yes        Yes             72           Yes
# 7041  Female             No     Yes        Yes             11            No
# 7042    Male             No      No         No             66           Yes
#
# ...

# %%
df_encoded=pd.get_dummies(df,drop_first=True)
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
# ...

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
X=df_encoded.drop('Churn Value',axis=1)
Y=df_encoded['Churn Value']
print(X.shape)
print(Y.shape)
# Out:
# (7043, 30)
# (7043,)

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (5634, 30)
# (1409, 30)
# (5634,)
# (1409,)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(Y_test,y_pred)
accuracy
# Out:
# 0.7856635911994322

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[902, 107],
#        [195, 205]])

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# ## **Approach 1 Handle Class Imbalance**

# %%
rf_balanced=RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')

# %%
rf_balanced.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred_bal=rf_balanced.predict(X_test)
y_pred_bal
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
accuracy_new=accuracy_score(Y_test,y_pred_bal)
accuracy_new
# Out:
# 0.7885024840312278

# %%
cm_balanced=confusion_matrix(Y_test,y_pred_bal)
cm_balanced
# Out:
# array([[835, 174],
#        [124, 276]])

# %%
print(classification_report(Y_test,y_pred_bal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1009
#            1       0.61      0.69      0.65       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.76      0.75      1409
# weighted avg       0.80      0.79      0.79      1409

# %% [markdown]
# ## Insights
# Accuracy increased than before

# %% [markdown]
# ## **Approach 2 Hyper Paramater Tuning**

# %%
rf_tuned=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')

# %%
rf_tuned.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=300,
#                        random_state=42)

# %%
y_pred_tuned=rf_tuned.predict(X_test)
y_pred_tuned
# Out:
# array([1, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
accuracy_new_tuned=accuracy_score(Y_test,y_pred_tuned)
accuracy_new_tuned
# Out:
# 0.765791341376863

# %%
cm_balanced=confusion_matrix(Y_test,y_pred_tuned)
cm_balanced
# Out:
# array([[764, 245],
#        [ 85, 315]])

# %%
print(classification_report(Y_test,y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1009
#            1       0.56      0.79      0.66       400
#
#     accuracy                           0.77      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.77      0.78      1409

# %% [markdown]
# ## **Approach 3 : Feature Importance Anaylysis**

# %%
import pandas as pd
features_importance=pd.DataFrame({'features':X.columns,'Importance':rf_tuned.feature_importances_})
sorted=features_importance.sort_values(by='Importance',ascending=False)
sorted
# Out:
#                                   features  Importance
# 0                            Tenure Months    0.181263
# 2                            Total Charges    0.129510
# 25                       Contract_Two year    0.107095
# 1                          Monthly Charges    0.092107
# 6                           Dependents_Yes    0.069950
# 10            Internet Service_Fiber optic    0.058224
# 28         Payment Method_Electronic check    0.045804
# 24                       Contract_One year    0.036634
# 13                     Online Security_Yes    0.029029
# 19                        Tech Support_Yes    0.021449
# 26                   Paperless Billing_Yes    0.018815
# 18        Tech Support_No internet service    0.015780
# 5                              Partner_Yes    0.015526
# 12     Online Security_No internet service    0.015416
# 22    Streaming Movies_No internet service    0.014900
# 16   Device Protection_No internet service    0.014825
# ...

# %%
X_selected=X.drop(['Phone Service_Yes','Multiple Lines_No phone service',],axis=1)
X_selected
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Multiple Lines_Yes  \
# 0                  False        False           False               False
# ...

# %%
X_selected_train,X_selected_test,Y_train_sel,Y_test_sel=train_test_split(X_selected,Y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Random Forest

# %%
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_selected.fit(X_selected_train,Y_train_sel)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=300,
#                        random_state=42)

# %%
y_pred_sel=rf_selected.predict(X_selected_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
print(classification_report(Y_test_sel,y_pred_sel))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1009
#            1       0.56      0.78      0.65       400
#
#     accuracy                           0.77      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.77      0.78      1409

# %% [markdown]
# ## **N_estimators and Depth Combinations**

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
max_depth_lst=[5,10,15,20]
n_estimators_lst=[100,200,300,400,500]
results=[]
for depth in max_depth_lst:
    for n_estimators in n_estimators_lst:
        rf=RandomForestClassifier(n_estimators=n_estimators,max_depth=depth,random_state=42,class_weight='balanced')
        rf.fit(X_train,Y_train)
        y_pred=rf.predict(X_test)
        accuracy=accuracy_score(Y_test,y_pred)
        recall=recall_score(Y_test,y_pred)
        precision=precision_score(Y_test,y_pred)
        f1=f1_score(Y_test,y_pred)
        results.append({"Trees":n_estimators,"Depth":depth,"Accuracy":accuracy,"Recall":recall,"Precision":precision,"F1":f1})
res=pd.DataFrame(results)
res=res.sort_values(by=['Recall','Accuracy'],ascending=False)
res
# Out:
#     Trees  Depth  Accuracy  Recall  Precision        F1
# 3     400      5  0.744500  0.8200   0.532468  0.645669
# 1     200      5  0.743790  0.8200   0.531605  0.645034
# 0     100      5  0.740241  0.8200   0.527331  0.641879
# 4     500      5  0.742370  0.8175   0.529984  0.643068
# 2     300      5  0.741661  0.8175   0.529126  0.642436
# 8     400     10  0.766501  0.7875   0.563506  0.656934
# 7     300     10  0.765791  0.7875   0.562500  0.656250
# 9     500     10  0.765791  0.7875   0.562500  0.656250
# 5     100     10  0.768630  0.7775   0.567518  0.656118
# 6     200     10  0.764372  0.7775   0.561372  0.651992
# 10    100     15  0.789212  0.7375   0.605749  0.665163
# 11    200     15  0.784954  0.7325   0.599182  0.659168
# 14    500     15  0.790632  0.7250   0.610526  0.662857
# 13    400     15  0.789212  0.7250   0.607966  0.661345
# 12    300     15  0.787793  0.7250   0.605428  0.659841
# 17    300     20  0.790632  0.6975   0.615894  0.654162
# ...

# %% [markdown]
# **Cross Validation**

# %%
from sklearn.model_selection import cross_val_score
final_model=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
scores=cross_val_score(final_model,X,Y,cv=5,scoring='accuracy')
scores
# Out:
# array([0.7523066 , 0.78495387, 0.75017743, 0.77201705, 0.76704545])

# %%
scores.mean()
# Out:
# np.float64(0.765300079843861)

# %%
scores1=cross_val_score(final_model,X,Y,cv=5,scoring='recall')

# %%
scores1.mean()
# Out:
# np.float64(0.762959670829092)

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
y_prob=rf_selected.predict_proba(X_selected_test)
y_prob
# Out:
# array([[0.27805224, 0.72194776],
#        [0.64247597, 0.35752403],
#        [0.73387077, 0.26612923],
#        ...,
#        [0.27765488, 0.72234512],
#        [0.90308575, 0.09691425],
#        [0.20736052, 0.79263948]], shape=(1409, 2))

# %%
churn_proba=y_prob[:,1]
fpr,tpr,threshold=roc_curve(Y_test,churn_proba)
aoc_score=roc_auc_score(Y_test,churn_proba)
print(aoc_score)
print(churn_proba)
# Out:
# 0.8567306739345887
# [0.72194776 0.35752403 0.26612923 ... 0.72234512 0.09691425 0.79263948]

# %% [markdown]
# ## **Customer Segmentation**

# %%
segmen=pd.DataFrame({'Tenure Months':X_selected_test['Tenure Months'],'Monthly Charges':X_selected_test['Monthly Charges'],'Total Charges':X_selected_test['Total Charges']
                     ,'Churn Probab':churn_proba})
segmen
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probab
# 185              15            85.90        1269.55      0.721948
# 2715             18            56.80        1074.65      0.357524
# 3825              2            20.00          40.90      0.266129
# 1807              6            84.20         519.15      0.829550
# 132              40           104.80        4131.95      0.518865
# ...             ...              ...            ...           ...
# 6366             66           104.90        6891.45      0.136183
# 315              19            86.00        1532.45      0.740785
# 2439              2            90.35         190.50      0.722345
# 5002             68           110.20        7467.50      0.096914
# 1161             30            99.70        2967.35      0.792639
#
# [1409 rows x 4 columns]

# %% [markdown]
# ## **K means**

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()
Scaler
# Out:
# StandardScaler()

# %%
scaled_data=Scaler.fit_transform(segmen)
scaled_data
# Out:
# array([[-0.69631406,  0.6691038 , -0.45048988,  1.06834098],
#        [-0.57429095, -0.31419848, -0.53600108, -0.13455975],
#        [-1.22508089, -1.55768728, -0.98955267, -0.43623846],
#        ...,
#        [-1.22508089,  0.81947133, -0.92391657,  1.06965259],
#        [ 1.45942762,  1.49021188,  2.26882336, -0.99478829],
#        [-0.08619849,  1.13541209,  0.29440965,  1.30168232]],
#       shape=(1409, 4))

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for k in range(1,16):
  kmeans=KMeans(n_clusters=k,random_state=42)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)
  plt.figure(figsize=(8,6))
plt.plot(range(1,16),wcss,marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,random_state=42)
clusters=kmeans.fit_predict(scaled_data)
print(clusters)
# Out:
# [0 1 1 ... 0 2 0]

# %%
segmen['Cluster']=clusters
segmen["Cluster"]
# Out:
# 185     0
# 2715    1
# 3825    1
# 1807    0
# 132     2
#        ..
# 6366    2
# 315     0
# 2439    0
# 5002    2
# 1161    0
# Name: Cluster, Length: 1409, dtype: int32

# %%
segmen
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probab  Cluster
# 185              15            85.90        1269.55      0.721948        0
# 2715             18            56.80        1074.65      0.357524        1
# 3825              2            20.00          40.90      0.266129        1
# 1807              6            84.20         519.15      0.829550        0
# 132              40           104.80        4131.95      0.518865        2
# ...             ...              ...            ...           ...      ...
# 6366             66           104.90        6891.45      0.136183        2
# 315              19            86.00        1532.45      0.740785        0
# 2439              2            90.35         190.50      0.722345        0
# 5002             68           110.20        7467.50      0.096914        2
# 1161             30            99.70        2967.35      0.792639        0
#
# [1409 rows x 5 columns]

# %%
cluster_summary=segmen.groupby('Cluster').mean()
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probab
# Cluster
# 0            11.113346        73.432176     902.117002      0.708495
# 1            32.421412        33.320957    1094.041800      0.154172
# 2            58.969267        90.632151    5346.985461      0.250500

# %%
cluster_summary={0:"Budget and Loyal",1:"High Risk Churn",2:"Premiun and Loyal"}
cluster_summary
# Out:
# {0: 'Budget and Loyal', 1: 'High Risk Churn', 2: 'Premiun and Loyal'}

# %%
segmen['Cluster Updated']=segmen['Cluster'].map(cluster_summary)
segmen
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probab  Cluster  \
# 185              15            85.90        1269.55      0.721948        0
# 2715             18            56.80        1074.65      0.357524        1
# 3825              2            20.00          40.90      0.266129        1
# 1807              6            84.20         519.15      0.829550        0
# 132              40           104.80        4131.95      0.518865        2
# ...             ...              ...            ...           ...      ...
# 6366             66           104.90        6891.45      0.136183        2
# 315              19            86.00        1532.45      0.740785        0
# 2439              2            90.35         190.50      0.722345        0
# 5002             68           110.20        7467.50      0.096914        2
# 1161             30            99.70        2967.35      0.792639        0
#
#         Cluster Updated
# 185    Budget and Loyal
# ...

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Churn Probab',hue='Cluster Updated',data=segmen)
plt.xlabel("Tenure Months")
plt.ylabel("Monthly Charges")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Total Charges',y='Churn Probab',hue='Cluster Updated',data=segmen)
plt.xlabel("Total Charges")
plt.ylabel("Monthly Charges")
plt.show()
